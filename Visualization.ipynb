# %% [markdown]
# Import Packages

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import os
import numpy as np
import plotly.express as px

# %%
data='/content/iris.csv'
iris=pd.read_csv(data)

# %%
pf.info()
pf.describe()
pf.value_counts('variety')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal.length  150 non-null    float64
#  1   sepal.width   150 non-null    float64
#  2   petal.length  150 non-null    float64
#  3   petal.width   150 non-null    float64
#  4   variety       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# variety
# Setosa        50
# Versicolor    50
# Virginica     50
# dtype: int64

# %%
os.getcwd()
# Out:
# '/content'

# %%
plt.figure(figsize = (10, 7))
x = pd.DataFrame({"sepallength":iris["sepal.length"],"variety":iris["variety"]})

x.pivot(columns='variety', values='sepallength').plot.hist()  
# plt.hist(x, bins = 20, color = "green")
plt.title("Sepal Length in cm")
plt.xlabel("Sepal_Length_cm")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize = (10, 7))
x = iris["sepal.length"]
  
plt.hist(x, bins = 20, color = "green")

plt.title("Sepal Length in cm")
plt.xlabel("Sepal_Length_cm")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
plt.figure(figsize = (10, 7))
x = iris["sepal.length"] 
y=iris['variety']
plt.hist(x, bins = 15)

plt.title("Sepal Length in cm")
plt.xlabel("Sepal_Length_cm")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
sns.boxplot(x="variety", y="sepal.width", data=iris)
plt.show()

# %%
fig,ax=plt.subplots()
c= np.array(['red', 'green', 'blue'])
variety=iris['variety']
ax.scatter(iris['sepal.length'],iris['petal.width'])
ax.set_title('Iris Dataset')
ax.set_xlabel('sepal length')
ax.set_ylabel('petal width')
# Out:
# Text(0, 0.5, 'petal width')

# %%
sns.FacetGrid(iris, hue="variety", height=4) \
   .map(plt.scatter, "sepal.length", "petal.width") \
   .add_legend()
plt.show()

# %%
sns.scatterplot(x='sepal.length',y='petal.width', hue='variety',data=iris)

# %%
sns.displot(x='variety',y='petal.length',data=iris)

# %%
px.scatter_matrix(iris,color='variety')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from pandas.plotting import parallel_coordinates
from pandas.plotting import andrews_curves
import plotly.express as px

# %%
andrews_curves(iris, "variety",colormap='rainbow')
plt.show()

# %%
fig=px.scatter(iris,x='petal.length',y='petal.width',color='variety',
               size='sepal.length',hover_data=['petal.width'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
x=iris['sepal.length'].to_numpy()
y=iris['petal.length'].to_numpy()
z=iris['sepal.length'].to_numpy()
colors=np.random.rand(len(z))
plt.scatter(x,y,s=z,c=colors)
plt.show()
